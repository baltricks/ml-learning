# %% [markdown]
# # My Public Journey to Machine Learning

# %% [markdown]
# In late 2020 I started my journey through the great area of ai and machine learning. I made my first steps inspired by *Deep Learning for Coders with fastai & PyTorch* by Jeremy Howard & Sylvain Gugger. And so this blog starts with the first models I created following the chapters of this wonderful book.

# %% [markdown]
# Please run all the following code cells while reading (if not executed by other readers).

# %%
# !pip install -Uqq fastbook
import fastbook
# Out:
#      |████████████████████████████████| 727kB 12.3MB/s
#      |████████████████████████████████| 1.1MB 33.8MB/s
#      |████████████████████████████████| 51kB 5.1MB/s
#      |████████████████████████████████| 194kB 55.1MB/s
#      |████████████████████████████████| 61kB 6.2MB/s

# %%
from fastbook import load_learner
from fastai.vision.widgets import widgets, PILImage, VBox

# %% [markdown]
# ## Good old bears

# %% [markdown]
# The first model I created was the ***bears*** model. If it's currently not loaded in the notebook, please [download](https://drive.google.com/file/d/1EpfPeH-BG3XfQvp53CPzmw9snUgCPMtJ/view?usp=sharing) my trained bears model and store it the notebooks file system (bears.pkl, size is 45 MB). Then load the learned model:

# %%
learn_inf = load_learner('bears.pkl')

# %% [markdown]
# If you can run the following code and see the 3 categories of the model, everything is fine with the model:

# %%
learn_inf.dls.vocab
# Out:
# ['black', 'grizzly', 'teddy']

# %% [markdown]
# You can run all the stuff for some nice test widgets and then upload and test the model with your images:

# %%
btn_upload = widgets.FileUpload()

out_pl = widgets.Output()
lbl_pred = widgets.Label()

btn_run = widgets.Button(description='Classify')
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
btn_run.on_click(on_click_classify)

VBox([widgets.Label('Select your bear to test the model!'), 
      btn_upload, btn_run, out_pl, lbl_pred])

# %% [markdown]
# How does it work? Give me your comment!
